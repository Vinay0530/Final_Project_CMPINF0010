# %% [markdown]
# # Introduction

# %% [markdown]
# #### To determine the best neighbothood in Pittsburgh we decided to find the safest neighborhood. We felt that the safest neighborhood would allow for the most optimal and comfortable space to live. We used three different data sets which were police incident blotter data, covid shots data, and firearm seizures data. We felt that these three different catorgoires were vital to a person trying to find the best neighborhood in a certain area.

# %% [markdown]
# ## Metric one: Police Incidents
#
# First, we need to import everything and read our files

# %%
#Imports
import pandas as pd
import numpy as np
import geopandas
# %matplotlib inline
import matplotlib.pyplot as plt

#Style
plt.style.use('dark_background')

#Read csv files
covidShotsData = pd.read_csv("CovidShotsDataPerNeighborhood.csv")
data = pd.read_csv("FirearmSeizureData.csv")
policeIncidentData = pd.read_csv("PoliceIncidentBlotter.csv")
nmap = geopandas.read_file("Neighborhoods/Neighborhoods_.shp")

# %% [markdown]
# Lets just take a look at the data to make sure it read correctly

# %%
policeIncidentData.head()
# Out:
#            PK       CCR  HIERARCHY         INCIDENTTIME  \
# 0 -3218234799  22156251          0  2022-09-26T10:48:00
# 1   291943355  22156290          0  2022-09-26T11:53:00
# 2   293365062  22165846         10  2022-10-13T07:35:00
# 3   293903564  22169167          6  2022-10-18T02:00:00
# 4   292498416  22159837          0  2022-10-02T13:00:00
#
#                                     INCIDENTLOCATION CLEAREDFLAG  \
# 0          200 Block Reifert St Pittsburgh, PA 15210           N
# 1            5000 Block 2nd Ave Pittsburgh, PA 15207           Y
# 2            2000 Block 5th Ave Pittsburgh, PA 15219           N
# 3         500 Block Lockhart St Pittsburgh, PA 15212           N
# 4  1600 Block Saw Mill Run Blvd Pittsburgh, PA 15210           N
#
#   INCIDENTNEIGHBORHOOD INCIDENTZONE INCIDENTHIERARCHYDESC  \
# 0            Knoxville            3                    99
# 1            Hazelwood            4                    99
# 2                Bluff            2           HARRASSMENT
# 3       East Allegheny            1                 THEFT
# 4            Brookline            6                    99
#
#                                             OFFENSES  INCIDENTTRACT  \
# 0                     9999 9999 - (Misc. Incident):          3001.0
# 1                     9999 9999 - (Misc. Incident):          1515.0
# 2                     2709 Harassment (Non-Specific)          103.0
# 3  3924 Theft of Property Lost, Mislaid or Delive...         2304.0
# 4                     9999 9999 - (Misc. Incident):          3206.0
#
#    COUNCIL_DISTRICT  PUBLIC_WORKS_DIVISION          X          Y
# 0               3.0                    5.0 -79.992114  40.408138
# 1               5.0                    3.0 -79.943686  40.408550
# 2               6.0                    3.0 -79.977533  40.438011
# 3               1.0                    1.0 -80.000065  40.452558
# 4               4.0                    5.0 -80.000631  40.399967

# %% [markdown]
# So the data read correctly, all we care about is how many times each neighborhood appears because that means there was an incident. So lets count how many times each neighborhood appears and make a new dataframe to hold the data

# %%
#Creates a new dataframe with the neighborhood and # of recorded incidents
incidentDf = pd.DataFrame(policeIncidentData["INCIDENTNEIGHBORHOOD"].value_counts())
incidentDf.reset_index(inplace=True)
incidentDf.columns = ['Neighborhood', 'incidents']

incidentDf
# Out:
#                  Neighborhood  incidents
# 0   Central Business District        253
# 1            South Side Flats        135
# 2                     Carrick        105
# 3            Mount Washington         96
# 4                East Liberty         79
# ..                        ...        ...
# 88                Summer Hill          2
# 89                    Oakwood          2
# 90             Swisshelm Park          2
# 91             Outside County          1
# 92                  Ridgemont          1
#
# [93 rows x 2 columns]

# %% [markdown]
# With our new dataframe, we can sort by number of incidents, so lets take a look at which neighborhoods have the least incidents

# %%
#Displays the 15 neighborhoods with the least incidents
incidentDf.sort_values('incidents').head(15)
# Out:
#       Neighborhood  incidents
# 92       Ridgemont          1
# 91  Outside County          1
# 89         Oakwood          2
# 86   Regent Square          2
# 90  Swisshelm Park          2
# 88     Summer Hill          2
# 87            Hays          2
# 85   East Carnegie          3
# 84   Outside State          3
# 83   New Homestead          4
# 82       St. Clair          4
# 81    Mount Oliver          4
# 79      Friendship          6
# 80         Windgap          6
# 78       Fairywood          7

# %% [markdown]
# And the most incidents

# %%
#Displays the 15 neighborhoods with the most incidents
incidentDf.sort_values('incidents', ascending=False).head(15)
# Out:
#                  Neighborhood  incidents
# 0   Central Business District        253
# 1            South Side Flats        135
# 2                     Carrick        105
# 3            Mount Washington         96
# 4                East Liberty         79
# 5                   Brookline         79
# 6                   Shadyside         72
# 7              Homewood North         63
# 8                   Hazelwood         63
# 10                North Shore         61
# 12                  Knoxville         61
# 9                    Sheraden         61
# 11   Lincoln-Lemington-Belmar         61
# 13         Marshall-Shadeland         60
# 14        Squirrel Hill South         60

# %% [markdown]
# To better visualize this, we can make a bar graph to display the data in an easier to read manner|

# %%
#Plots the 15 neighborhoods with the most incidents
incidentDf.set_index('Neighborhood').head(15).plot(kind='bar')

# %%
#Plots the 15 neighborhoods with the least incidents
incidentDf.set_index('Neighborhood').tail(15).plot(kind='bar')

# %% [markdown]
# Lets take a look geographically where the neighborhoods are located in relation to pittsburgh as a whole, we can see where the safer places are with this map

# %%
#Merges the map of pittsburgh with the police incident data
count_val = incidentDf.groupby("Neighborhood").sum('incidents')
count_map = nmap.merge(count_val, how='left', left_on='hood', right_on='Neighborhood')

#Displays the map
count_map.plot(column='incidents',
               cmap='PuBu',
               edgecolor="white",
               legend=True,
               legend_kwds={'label': "Incidents"},
               figsize=(15, 10),
               missing_kwds={"color": "white"}
               )

# %% [markdown]
# ## Metric Two: Covid Shots

# %% [markdown]
# #### Importing pandas

# %%
import pandas as pd

# %% [markdown]
# #### I read the CSV file that cotains the neighborhoods in Pittsburgh with the amount of COVID-19 vaccine shots for each of them. I chose this data set because a safe neighborhood should include people with COVID-19 vaccines to prevent the disease from spreading.

# %%
covidShotsData = pd.read_csv("CovidShotsDataPerNeighborhood.csv")

# %% [markdown]
# #### I displayed first five rows of dataframe.

# %%
covidShotsData.head()
# Out:
#   neighborhood_municipality  total_partially_vaccinated  \
# 0            Bradford Woods                          92
# 1             North Fayette                         984
# 2     Garfield (Pittsburgh)                         359
# 3                   Forward                          81
# 4                      Pine                        1358
#
#    total_fully_vaccinated  total_fully_vaccinated_w_booster
# 0                     433                               523
# 1                    4577                              3759
# 2                    1139                              1071
# 3                     468                               425
# 4                    4930                              5143

# %% [markdown]
# #### I displayed the top 15 neigborhoods with the least amount of totally fully vaccinated people with booster shots. I also decided to only consider data from the total_fully_vaccinated_w_booster column for each of the neighborhoods for my metric.

# %%
covidShotsData.sort_values('total_fully_vaccinated_w_booster').head(15)
# Out:
#           neighborhood_municipality  total_partially_vaccinated  \
# 67                         Mcdonald                           2
# 86                         Trafford                           0
# 44             Chateau (Pittsburgh)                           8
# 191                       Haysville                           3
# 98   Arlington Heights (Pittsburgh)                          23
# 84           Undefined (Pittsburgh)                           4
# 32           St. Clair (Pittsburgh)                          27
# 95              Esplen (Pittsburgh)                          19
# 78            West End (Pittsburgh)                          28
# 144        South Shore (Pittsburgh)                          66
# 171                       Glenfield                          22
# 77                 South Versailles                          17
# 139                  West Elizabeth                          22
# 219               Hays (Pittsburgh)                          26
# 9          North Shore (Pittsburgh)                          56
#
#      total_fully_vaccinated  total_fully_vaccinated_w_booster
# 67                        1                                 0
# 86                        2                                 3
# 44                       24                                14
# 191                      22                                21
# 98                       63                                24
# 84                       24                                25
# 32                       81                                43
# 95                       82                                53
# 78                       84                                58
# 144                     109                                63
# 171                      64                                64
# 77                      109                                77
# 139                     143                                84
# 219                     120                                88
# 9                       157                                96

# %% [markdown]
# #### I displayed the top 15 neigborhoods with the most amount of totally fully vaccinated people with booster shots.

# %%
covidShotsData.sort_values('total_fully_vaccinated_w_booster').tail(15)
# Out:
#             neighborhood_municipality  total_partially_vaccinated  \
# 35                              Scott                        1428
# 37   Squirrel Hill South (Pittsburgh)                        2395
# 118                     Franklin Park                        1363
# 27                            Hampton                        1486
# 87                    Baldwin Borough                        1362
# 153                              Moon                        2205
# 172                              Plum                        1689
# 168                 Upper Saint Clair                        1842
# 214                       Monroeville                        2400
# 204                            Shaler                        1727
# 151                        McCandless                        2282
# 141                        Penn Hills                        2766
# 161                              Ross                        2302
# 194                       Bethel Park                        2197
# 33                      Mount Lebanon                        3228
#
#      total_fully_vaccinated  total_fully_vaccinated_w_booster
# 35                     6444                              6736
# 37                     5699                              6736
# 118                    5262                              6853
# 27                     6032                              7865
# 87                     7081                              7938
# 153                    8967                              8825
# 172                    8888                              9437
# 168                    7253                              9477
# 214                    9834                             10174
# 204                    8884                             11623
# 151                    9688                             12510
# 141                   12880                             12758
# 161                   11155                             13584
# 194                   10691                             14191
# 33                    11180                             16287

# %% [markdown]
# #### I displayed a bar graph that shows the top 15 neighborhoods with the most amount of totally fully vaccinated people with booster shots.

# %%
covidShotsData.set_index('neighborhood_municipality').nlargest(15, ['total_fully_vaccinated_w_booster']).plot(kind='bar')

# %% [markdown]
# #### I displayed a bar graph that shows the top 5 neighborhoods with the most amount of totally fully vaccinated people with booster shots.

# %%
covidShotsData.set_index('neighborhood_municipality').nlargest(5, ['total_fully_vaccinated_w_booster']).plot(kind='bar')

# %% [markdown]
# #### I came to the conclusion for my dataset that involved just the fully vaccinated with booster column that Mount Lebanon is the safest neighborhood. Since this neighborhood had the most amount of people that were fully vaccinated with booster shots.

# %% [markdown]
# ## Metric Three: Firearm Seizures

# %% [markdown]
# To determine the safest neighborhood, I compared the number of Pittsburgh police firearm seizures per neighborhood and the total number of firearms seized. A safe neighborhood should have little to no firearms seized, because that means that there are no unattended firearms that could get into the hands of the wrong person. Also, a high number of incidents where firearms were seized could mean that there were people in the area that were using the firearms for a potential criminal offence.
#
# First, I found the number of instances in each neighborhood through iteration and dictionaries. I then sorted the values in the dictionary from least number of instances to the greatest number of instances.

# %%
## Frequency of each neighborhood
freq = {}

for index, row in data.iterrows():
    hood = row['neighborhood']
    if hood not in freq:
        freq[hood] = 1
    else:
        freq[hood] += 1

## Sorts dictionary from least to greatest 
marklist = sorted(freq.items(), key=lambda x:x[1])
sortdict = dict(marklist)
print(sortdict)
# Out:
# {'Swisshelm Park': 1, 'Summer Hill': 2, 'Friendship': 3, 'Mt. Oliver': 3, 'Chartiers City': 4, 'Regent Square': 4, 'St. Clair': 4, 'Oakwood': 4, 'West End': 6, 'Mount Oliver Borough': 7, 'Fairywood': 7, 'Hays': 7, 'Arlington Heights': 8, 'Bon Air': 8, 'Lincoln Place': 8, 'Spring Garden': 9, 'Esplen': 9, 'Westwood': 10, 'Polish Hill': 10, 'Banksville': 10, 'Squirrel Hill North': 10, 'Upper Lawrenceville': 11, 'Windgap': 11, 'South Shore': 12, 'Morningside': 12, 'Lower Lawrenceville': 13, 'West Oakland': 13, 'Stanton Heights': 13, 'Glen Hazel': 13, 'North Oakland': 14, 'South Oakland': 15, 'Allegheny Center': 15, 'Duquesne Heights': 15, 'Allegheny West': 16, 'Central Oakland': 16, 'North Shore': 16, 'Point Breeze North': 17, 'Greenfield': 22, 'Chateau': 22, 'Strip District': 22, 'Central Lawrenceville': 22, 'Point Breeze': 23, 'Overbrook': 25, 'Shadyside': 25, 'Arlington': 28, 'Upper Hill': 28, 'California-Kirkbride': 29, 'Highland Park': 30, 'Perry North': 33, 'Troy Hill': 33, 'Squirrel Hill South': 33, 'South Side Slopes': 36, 'Bloomfield': 38, 'Elliott': 39, 'Terrace Village': 40, 'Crafton Heights': 42, 'Beltzhoover': 43, 'Northview Heights': 48, 'Bluff': 49, 'Crawford-Roberts': 50, 'Homewood West': 51, 'Brookline': 51, 'East Allegheny': 51, 'Central Northside': 59, 'Fineview': 61, 'Beechview': 64, 'Manchester': 64, 'Allentown': 65, 'Spring Hill-City View': 65, 'Bedford Dwellings': 68, 'East Liberty': 74, 'Mount Washington': 78, 'Garfield': 78, 'Brighton Heights': 81, 'Middle Hill': 88, 'Knoxville': 96, 'Lincoln-Lemington-Belmar': 101, 'Marshall-Shadeland': 104, 'East Hills': 106, 'Larimer': 107, 'Sheraden': 108, 'Perry South': 110, 'Central Business District': 111, 'Hazelwood': 112, 'Carrick': 114, 'Homewood North': 130, 'South Side Flats': 177, 'Homewood South': 250, nan: 771}

# %% [markdown]
# Then, I converted the dictionary into a dataframe. The graph shows each neighborhood and their firearm seizure incidents, from least to greatest.

# %%
newDict = pd.DataFrame([sortdict])
newDict = newDict.T
newDict.plot(kind='bar', width = .4, figsize = (25,10), ylim = (0,200))

# %% [markdown]
# Finally, I plotted the data onto a bar graph to show the 5 neighborhoods with the least number of firearm seizures. The 5 from least to greatest were Swisshelm Park, Summer Hill, Friendship, Mt. Oliver, and Chartiers City.

# %%
df = newDict.head(5)
print(df)
df.plot(kind='bar')
# Out:
#                 0
# Swisshelm Park  1
# Summer Hill     2
# Friendship      3
# Mt. Oliver      3
# Chartiers City  4

# %% [markdown]
# My final step is to take the number of total firearms seized per neighborhood, and compare the results to the number of incidents. I repeated the same process for total firearms seized.
#
# Here, I found the total number of firearms seized per neighborhood. I sorted them from least to greatest in a dictionary.

# %%
## Finds total firearms seized per neighborhood
num = {}
for index, row in data.iterrows():
    hood = row['neighborhood']
    total = row['total_count']
    if hood not in num:
        num[hood] = total
    else:
        num[hood] += total

## Sorts totals
updated = sorted(num.items(), key=lambda x:x[1])
sortNum = dict(updated)
print(sortNum)
# Out:
# {'Summer Hill': 3, 'Mt. Oliver': 3, 'Swisshelm Park': 3, 'Chartiers City': 4, 'Regent Square': 4, 'Oakwood': 4, 'Friendship': 5, 'West End': 6, 'St. Clair': 7, 'Hays': 8, 'Mount Oliver Borough': 9, 'Fairywood': 9, 'Westwood': 10, 'Arlington Heights': 10, 'Polish Hill': 10, 'Banksville': 10, 'Lincoln Place': 10, 'Esplen': 10, 'Spring Garden': 11, 'Bon Air': 12, 'South Shore': 13, 'West Oakland': 14, 'Stanton Heights': 14, 'Squirrel Hill North': 14, 'Glen Hazel': 15, 'Windgap': 15, 'Lower Lawrenceville': 17, 'Allegheny West': 17, 'Allegheny Center': 17, 'Point Breeze North': 19, 'Duquesne Heights': 19, 'Upper Lawrenceville': 20, 'North Oakland': 20, 'Central Oakland': 20, 'North Shore': 20, 'South Oakland': 21, 'Strip District': 24, 'Greenfield': 25, 'Chateau': 26, 'Central Lawrenceville': 26, 'Morningside': 28, 'Overbrook': 29, 'Shadyside': 29, 'Point Breeze': 30, 'California-Kirkbride': 33, 'Upper Hill': 37, 'South Side Slopes': 39, 'Arlington': 40, 'Troy Hill': 40, 'Highland Park': 41, 'Perry North': 44, 'Terrace Village': 45, 'Beltzhoover': 46, 'Squirrel Hill South': 47, 'Northview Heights': 56, 'East Allegheny': 56, 'Elliott': 56, 'Homewood West': 57, 'Bluff': 57, 'Crawford-Roberts': 57, 'Bloomfield': 58, 'Crafton Heights': 61, 'Manchester': 72, 'Fineview': 74, 'Spring Hill-City View': 77, 'Brookline': 79, 'Bedford Dwellings': 82, 'Central Northside': 83, 'Allentown': 89, 'Mount Washington': 90, 'Garfield': 91, 'Middle Hill': 96, 'Beechview': 100, 'Knoxville': 119, 'Sheraden': 121, 'Central Business District': 124, 'Larimer': 126, 'East Hills': 134, 'Perry South': 134, 'Lincoln-Lemington-Belmar': 134, 'Marshall-Shadeland': 144, 'Hazelwood': 144, 'Carrick': 144, 'Brighton Heights': 148, 'East Liberty': 148, 'Homewood North': 159, 'South Side Flats': 205, 'Homewood South': 343, nan: 988}

# %% [markdown]
# Next, I created a bar chart to represent the total number of firearms seized per neighborhood

# %%
updateDict = pd.DataFrame([sortNum])
updateDict = updateDict.T
updateDict.plot(kind='bar', width = .4, figsize = (25,10), ylim = (0,200))

# %% [markdown]
# Finally, I created a dataframe for the top 5 lowest total firearms sezied, and plotted them on a bar graph.

# %%
df2 = updateDict.head(5)
print(df2)
df2.plot(kind='bar')
# Out:
#                 0
# Summer Hill     3
# Mt. Oliver      3
# Swisshelm Park  3
# Chartiers City  4
# Regent Square   4

# %% [markdown]
# The results point to Swisshelm Park being the safest neighborhood (off of this metric). It had the lowest number of firearm seizure incidents, and the joint-lowest number of total firearms seized.

# %% [markdown]
# ## The Best Neighborhood

# %% [markdown]
# In order to determine the best overall neighborhood, it must consistantly rank high in each data set

# %% [markdown]
# Best Neighborhood: Swisshelm park

# %% [markdown]
# Swisshelm park ranks 3rd in 2/3 subsets, and the only reason it does not rank highly in covid shots is because that dataset looks at total covid shots, not at shots in comparison to the population, and Swisshelm has a fairly low population at just over 1000

# %% [markdown]
# ## Conclusion
#
# Alek: The ranking of this data is a lot based on crime because well, that is what makes a neighborhood safe. I did notice the neighborhoods where the colleges are extremely skewed to make the area look really bad, when in reality its just because its a bunch of college kids living in the area. for Example, there are so many police incidents in comparison to the other neighborhoods in downtown pittsburgh, making the area look very bad with it could just be college kids drinking or committing other insignificant offenses
#
# Vinay: I have not been to Swisshelm park personally but based on the low crime incident rate and firearm seizure rate it seems like an acceptable neighborhood. Also, the total amount of people that are totally fully vaccinated and have boosters shots in Swisshelm park is around 625 people which is over half of the population. This proves even further that Swisshelm park would be a safe neighborhood for people to live in and I would put this as one of my personal favorite neighborhoods.
#
#
# Nico: Firearm seizures are a result of suspicious activity in an area, and a high firearm seizure count can indicate the safety level of a given area. Likewise, a high number of firearms seized can also indicate the safety of an area, so the best way to measure this is based off which neighborhood had the lowest number of firearm seizures, and the least number of total firearms seized. Swisshelm Park seems to be the safest out of the neighborhoods, because it has the single-lowest number of firearm seizures, and the joint-lowest total firearms seized. It also has a low crime incident rate, and a majority of the population is vaccinated.
